# %%
import pandas as pd

# %%
data=pd.read_excel('../../data/sample.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data=pd.read_excel('../../data/sample.xlsx')
#
# File ~/Desktop/High margin/hm/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
data.head()
# Out:
#    StoreId       Date CheckTime  UniqueCheckId    PLU  MenuItemId  \
# 0     1052 2023-02-08  12:34:00  3923010523082  47584          68
# 1     1052 2023-02-08  12:34:00  3923010523082  49020         212
# 2     1052 2023-02-08  12:34:00  3923010523082  50198           6
# 3     1052 2023-02-08  12:34:00  3923010523082  49107          71
# 4     1052 2023-02-08  12:34:00  3923010523082  51844        1179
#
#                       MenuItemName  ItemCount  Amount   Tax  LineType  \
# 0                      Add Lettuce          1    0.00  0.00         1
# 1               Medium Potato Oles          1    2.99  0.21         1
# 2  The Boss Bowl - Grilled Chicken          1    6.69  0.48         1
# 3                    Pico de Gallo          1    0.00  0.00         1
# 4                 More Ingredients          1    0.00  0.00         1
#
#   LineTypeDescription  CategoryName  ReductionId  ReductionName order_channel  \
# ...
